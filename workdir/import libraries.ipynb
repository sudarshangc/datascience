# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GDP=pd.read_excel('../Data/GDP.xls', skiprows=5)

# %%
GDP
# Out:
#                            Gross domestic product 2016  Unnamed: 1  \
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                            Ranking         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# USA                                                  1         NaN
# CHN                                                  2         NaN
# JPN                                                  3         NaN
# DEU                                                  4         NaN
# GBR                                                  5         NaN
# FRA                                                  6         NaN
# IND                                                  7         NaN
# ITA                                                  8         NaN
# ...

# %%
GDP.head()
# Out:
#   Unnamed: 0 Unnamed: 1  Unnamed: 2     Unnamed: 3 (millions of Unnamed: 5
# 0        NaN    Ranking         NaN        Economy  US dollars)        NaN
# 1        NaN        NaN         NaN            NaN          NaN        NaN
# 2        NaN        NaN         NaN            NaN          NaN        NaN
# 3        USA          1         NaN  United States     18569100        NaN
# 4        CHN          2         NaN          China  1.11991e+07        NaN
