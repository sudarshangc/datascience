# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
# %matplotlib inline

# %%
agland=pd.read_excel('../Data/agland.xls')

# %%
agland
# Out:
#                                            Data Source  \
# 0                                    Last Updated Date
# 1                                                  NaN
# 2                                         Country Name
# 3                                                Aruba
# 4                                          Afghanistan
# 5                                               Angola
# 6                                              Albania
# 7                                              Andorra
# 8                                           Arab World
# 9                                 United Arab Emirates
# 10                                           Argentina
# 11                                             Armenia
# 12                                      American Samoa
# 13                                 Antigua and Barbuda
# 14                                           Australia
# 15                                             Austria
# ...

# %%
agland=pd.read_excel('../Data/agland.xls',skiprows=3)

# %%
agland
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
agland.head(3)
# Out:
#   Country Name Country Code                      Indicator Name  \
# 0        Aruba          ABW  Agricultural land (% of land area)
# 1  Afghanistan          AFG  Agricultural land (% of land area)
# 2       Angola          AGO  Agricultural land (% of land area)
#
#    Indicator Code  1960       1961       1962       1963       1964  \
# 0  AG.LND.AGRI.ZS   NaN  11.111111  11.111111  11.111111  11.111111
# 1  AG.LND.AGRI.ZS   NaN  57.745918  57.837821  57.914407  58.010906
# 2  AG.LND.AGRI.ZS   NaN  45.857063  45.881126  45.897169  45.921232
#
#         1965  ...        2007       2008       2009       2010       2011  \
# 0  11.111111  ...   11.111111  11.111111  11.111111  11.111111  11.111111
# 1  58.013969  ...   58.067580  58.067580  58.067580  58.067580  58.069111
# 2  45.937274  ...   46.274164  46.274164  46.755434  46.835646  47.316917
#
#         2012       2013       2014  2015  2016
# 0  11.111111  11.111111  11.111111   NaN   NaN
# ...

# %%
agland.head()
# Out:
#   Country Name Country Code                      Indicator Name  \
# 0        Aruba          ABW  Agricultural land (% of land area)
# 1  Afghanistan          AFG  Agricultural land (% of land area)
# 2       Angola          AGO  Agricultural land (% of land area)
# 3      Albania          ALB  Agricultural land (% of land area)
# 4      Andorra          AND  Agricultural land (% of land area)
#
#    Indicator Code  1960       1961       1962       1963       1964  \
# 0  AG.LND.AGRI.ZS   NaN  11.111111  11.111111  11.111111  11.111111
# 1  AG.LND.AGRI.ZS   NaN  57.745918  57.837821  57.914407  58.010906
# 2  AG.LND.AGRI.ZS   NaN  45.857063  45.881126  45.897169  45.921232
# 3  AG.LND.AGRI.ZS   NaN  44.963504  44.963504  45.000000  44.890511
# 4  AG.LND.AGRI.ZS   NaN  55.319149  55.319149  55.319149  55.319149
#
#         1965  ...        2007       2008       2009       2010       2011  \
# 0  11.111111  ...   11.111111  11.111111  11.111111  11.111111  11.111111
# ...

# %%
agland=agland.set_index('Country Name')

# %%
agland
# Out:
#                                                    Country Code  \
# Country Name
# Aruba                                                       ABW
# Afghanistan                                                 AFG
# Angola                                                      AGO
# Albania                                                     ALB
# Andorra                                                     AND
# Arab World                                                  ARB
# United Arab Emirates                                        ARE
# Argentina                                                   ARG
# Armenia                                                     ARM
# American Samoa                                              ASM
# Antigua and Barbuda                                         ATG
# Australia                                                   AUS
# Austria                                                     AUT
# ...

# %%
agland.set_index('1960')
# Out:
#      Country Code                      Indicator Name  Indicator Code  \
# 1960
# NaN           ABW  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           AFG  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           AGO  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           ALB  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           AND  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           ARB  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           ARE  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           ARG  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           ARM  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           ASM  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           ATG  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# NaN           AUS  Agricultural land (% of land area)  AG.LND.AGRI.ZS
# ...

# %%
agland
# Out:
#                                                    Country Code  \
# Country Name
# Aruba                                                       ABW
# Afghanistan                                                 AFG
# Angola                                                      AGO
# Albania                                                     ALB
# Andorra                                                     AND
# Arab World                                                  ARB
# United Arab Emirates                                        ARE
# Argentina                                                   ARG
# Armenia                                                     ARM
# American Samoa                                              ASM
# Antigua and Barbuda                                         ATG
# Australia                                                   AUS
# Austria                                                     AUT
# ...

# %%
agland.shape
# Out:
# (264, 60)
